# %%
"""
Check sessions available with dlc data
@author: Ines
"""
import pandas as pd
import math
from pathlib import Path
import pickle 
import csv
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import numpy as np
from one.api import ONE
from uuid import UUID

# Get my functions
functions_path =  '/home/ines/repositories/representation_learning_variability/Functions/'
functions_path = '/Users/ineslaranjeira/Documents/Repositories/representation_learning_variability/Functions/'
os.chdir(functions_path)
from one_functions_generic import query_subjects_interest, subjects_interest_data, prepro
# Out:
# /opt/anaconda3/envs/iblenv/lib/python3.9/site-packages/one/webclient.py:127: RuntimeWarning: Failed to connect, returning cached response
#   warnings.warn('Failed to connect, returning cached response', RuntimeWarning)

# %% [markdown]
# ### Naive sessions trained on dlc by Michael

# %%
naive_sessions = ['fb9bdf18-76be-452b-ac4e-21d5de3a6f9f',
       'b117ed10-6871-42b3-9193-ca708dac4353',
       'db71a948-f414-4b44-afd6-45d45d127339',
       '895abba6-7ca1-44e7-b43f-e3cb43e850e7',
       '72578193-48bc-4c4c-a0c2-0954ae6f3b0c',
       '1aa50555-8acc-4fd5-b662-5206f3366f79',
       'b93a501c-3136-4129-a05f-ee47b90a6be7',
       '3271651b-33aa-4caf-9a23-1d813eb90593',
       'e00db9dd-b30a-4388-b7e2-7f54b342fc8d',
       '93ac89cc-89b8-4271-a40e-094b19d9fe78',
       '1ab810bb-1363-48a1-9a27-b6f9e56f95b1',
       '4c5702bf-01ca-4236-840d-9319a719f77f',
       '0bade8f5-fed5-49d0-ada9-ce310c8f4278',
       '34d2ab51-3a28-4d42-93b7-5d186bc57bbc',
       '9811969a-59f1-446a-bbdd-2b151f434097',
       '94fc857c-2332-419b-bf1b-110923355479',
       '34f045d9-e0c0-4dd4-82ed-98ce72afd8f5',
       'd67e094f-086f-48df-8d29-7c70614612a0',
       'dc990d49-4e51-4759-992b-292fbe22a7eb',
       'e7850826-9626-48d9-8a5a-e704bd9e6a5c',
       '6ecf1d29-4448-4332-b849-0764a856c2e3',
       'd7be2c7d-5dba-4083-9744-8c976e62fb43',
       '38bf926a-8e18-49db-8ee5-51f9fd0398f7',
       'e2c420b4-a23a-46aa-9ab5-1e82d6ffacc9',
       '69037c65-225f-4310-86f8-fdc3b9e35849',
       '8781d8bb-6ef4-4801-a82d-eb69b6009b48',
       '091fe0b7-138c-4f1f-9cd5-c4ffa275fb2f',
       '85da07f3-b1d4-439d-858d-5e0329a90b6f',
       '4ab187c7-a351-4bad-a6e8-dc5cdcac4196',
       '42a9949d-41c6-42ba-aee6-bc9fc0b5d728',
       'e777cadc-4d58-416f-b252-f80a31c02cca',
       '7ae52e2d-19d2-4983-8560-ce56fdcfee1c',
       '0f86be49-ca63-4134-8e36-1b29561abaaf',
       '953c20ee-0297-46b7-afdd-9af38a62d045',
       '8eaea787-11c0-46c0-aecd-80356be3d43c',
       '8a6557e8-5621-4ac8-a2dd-31070bdad530',
       '49816bfc-ef84-495c-a433-318ceac5addf',
       '28ed1dfe-70fe-497a-904c-c2e90c0e04d8',
       '5a481d99-7532-47d0-aab5-8f055fb2a378',
       '1c581f5e-952a-48cd-b203-1901f02f77f7',
       '192e911a-86e3-4ca2-bc42-9c29085c28ad',
       '5d111796-040a-4bf8-b6d3-e3cac7a74c8d',
       '5e873c77-ba6c-4c00-887c-cc89d922fbce',
       'a903eb60-5909-45f1-b64b-ffcbedd4b679',
       '3adeafca-5a8b-49da-8cce-6dad741d24a8']

# %%
video_type = 'left'
query_type = 'remote'
one = ONE()
good_sessions = []
for s, session in enumerate(naive_sessions):
    times = one.list_datasets(session, '*leftCamera.times.npy*')
    dlc = collections = one.list_datasets(session, '*leftCamera.dlc*')
    if (len(times) > 0) & (len(dlc) > 0):
        if len(good_sessions) == 0:
            good_sessions = [session]
        else:
            good_sessions = np.append(good_sessions, [session])
    else:
        print(str('Session missing ' + session))
# Out:
# /opt/anaconda3/envs/iblenv/lib/python3.9/site-packages/one/webclient.py:127: RuntimeWarning: Failed to connect, returning cached response
#   warnings.warn('Failed to connect, returning cached response', RuntimeWarning)
# Session missing fb9bdf18-76be-452b-ac4e-21d5de3a6f9f
# Session missing db71a948-f414-4b44-afd6-45d45d127339
# Session missing 72578193-48bc-4c4c-a0c2-0954ae6f3b0c
# Session missing 1aa50555-8acc-4fd5-b662-5206f3366f79
# Session missing b93a501c-3136-4129-a05f-ee47b90a6be7
# Session missing e00db9dd-b30a-4388-b7e2-7f54b342fc8d
# Session missing 4c5702bf-01ca-4236-840d-9319a719f77f
# Session missing 0bade8f5-fed5-49d0-ada9-ce310c8f4278
# Session missing 34d2ab51-3a28-4d42-93b7-5d186bc57bbc
# Session missing 34f045d9-e0c0-4dd4-82ed-98ce72afd8f5
# Session missing e7850826-9626-48d9-8a5a-e704bd9e6a5c
# Session missing 6ecf1d29-4448-4332-b849-0764a856c2e3
# Session missing d7be2c7d-5dba-4083-9744-8c976e62fb43
# Session missing 38bf926a-8e18-49db-8ee5-51f9fd0398f7
# ...

# %% [markdown]
# ### Get mouse names of the good naive video sessions

# %% [markdown]
# https://int-brain-lab.github.io/ONE/notebooks/one_search/one_search.html

# %%
# transform sessions into subjects
subjects_naive = []

for s, session in enumerate(good_sessions):
    session_details = one.list_datasets(session, details=True)
    parts = session_details['session_path'][0].split('/')
    mouse_name = '/'.join(parts[2:3])
    
    if len(subjects_naive) == 0:
        subjects_naive = [mouse_name]
    else:
        subjects_naive = np.append(subjects_naive, [mouse_name])

# %% [markdown]
# ### Get proficient mice

# %%
# Get subjects of interest with ephys data
subjects_prof = query_subjects_interest(protocol='ephys', ibl_project='ibl_neuropixel_brainwide_01')

# %% [markdown]
# ### Intersect mice with both naif and expert video data

# %%
intersection = np.intersect1d(subjects_naive, subjects_prof)
save_path =  '/home/ines/repositories/representation_learning_variability/Video/'
save_path = '/Users/ineslaranjeira/Documents/Repositories/representation_learning_variability/Video/'
os.chdir(save_path)
pickle.dump(intersection, open("subject_intersection", "wb"))
pickle.dump(good_sessions, open("good_naive_sessions", "wb"))
