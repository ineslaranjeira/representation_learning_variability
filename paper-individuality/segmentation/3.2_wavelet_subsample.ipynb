# %% [markdown]
# ## PAW wavelet decomposition

# %%
""" 
IMPORTS
"""
import os
import numpy as np
import pandas as pd
from one.api import ONE
from sklearn.manifold import TSNE
from scipy import stats

# Get my functions
from segmentation_functions import idxs_from_files, plot_kde
one = ONE(mode='remote')

# %%
""" 
LOAD DATA AND PARAMETERS
"""
# LOAD DATA
var = 'paw'
velocity = True

base_path = '/Users/ineslaranjeira/Google Drive/O meu disco/CCU/PhD Project/paper-individuality/data/newly_generated/segmentation/'
data_path = base_path + 'design_matrices/'

all_files = os.listdir(data_path)
design_matrices = [item for item in all_files if 'design_matrix' in item and 'standardized' not in item]
idxs, mouse_names = idxs_from_files(design_matrices)

if var == 'paw':
    wavelet_path = base_path + 'paw_wavelets/'
elif var == 'wheel':
    wavelet_path = base_path + 'wheel_wavelets/'

# %%
# Loop through animals
files = os.listdir(wavelet_path)
sessions_to_process = []

for m, mat in enumerate(idxs):
    mouse_name = mat[37:]
    session = mat[:36]

    """ SAVE DATA """       
    # Save wavelets
    if var == 'paw':
        if velocity:
            subname = "paw_vel_wavelets_"
        else:
            subname = "paw_pos_wavelets_"
    elif var == 'wheel':
        subname = 'wheel_vel_wavelets_'
    
    filename = subname + str(session) + '_'  + mouse_name

    if filename in files:
        sessions_to_process.append((mouse_name, session))
    
print(len(sessions_to_process))
# Out:
# 318

# %% [markdown]
# # Subsample

# %%
if var == 'paw':
    var_interest = ['l_paw_x', 'l_paw_y', 'r_paw_x', 'r_paw_y', 
                    'l_paw_x0.5', 'l_paw_x1.0', 'l_paw_x2.0', 'l_paw_x4.0', 'l_paw_x8.0', 'l_paw_x16.0', 'l_paw_x32.0',
                    'l_paw_y0.5', 'l_paw_y1.0', 'l_paw_y2.0', 'l_paw_y4.0', 'l_paw_y8.0', 'l_paw_y16.0', 'l_paw_y32.0',
                    'r_paw_x0.5', 'r_paw_x1.0', 'r_paw_x2.0', 'r_paw_x4.0', 'r_paw_x8.0', 'r_paw_x16.0', 'r_paw_x32.0',
                    'r_paw_y0.5', 'r_paw_y1.0', 'r_paw_y2.0', 'r_paw_y4.0', 'r_paw_y8.0', 'r_paw_y16.0', 'r_paw_y32.0']
elif var == 'wheel':
    var_interest = ['avg_wheel_vel0.5', 'avg_wheel_vel1.0', 'avg_wheel_vel2.0', 'avg_wheel_vel4.0', 'avg_wheel_vel8.0', 
                    'avg_wheel_vel16.0', 'avg_wheel_vel32.0']

# %%
# Check files to process
subsamples_path = base_path + 'subsampled_wavelets/' 
files = os.listdir(subsamples_path)
left_sessions_to_process = []

for m, mat in enumerate(sessions_to_process):
    mouse_name = mat[0]
    session = mat[1]
    filename = str(session) + '_'  + mouse_name + '.npy'
    if filename not in files:
        left_sessions_to_process.append((mouse_name, session))

print(len(left_sessions_to_process))
# Out:
# 129

# %%
for m, mat in enumerate(left_sessions_to_process):

    mouse_name = mat[0]
    session = mat[1]
    filename = wavelet_path + subname + str(session) + '_'  + mouse_name
    design_matrix = pd.read_parquet(filename)

    # Prepare data
    data_df = design_matrix[var_interest].copy().dropna()
    data = np.array(data_df)
    
    """ Randomly subsample """
    n_samples = 20000
    sampled_indices = np.random.choice(data.shape[0], 
                                       n_samples, 
                                       replace=False)
    sampled_data = data[sampled_indices, :]
    
    # """ Perform t-SNE """
    # X = sampled_data.copy()
    # X_embedded = TSNE(n_components=2, learning_rate='auto',
    #               init='random', perplexity=32).fit_transform(X)
    # # plt.scatter(X_embedded[:, ], X_embedded[:, 1], alpha=0.02)
    # # plt.show()
    
    # """ Perform Gaussian kde """
    # values = X_embedded.T.copy()
    # kernel = stats.gaussian_kde(values)
    # # plot_kde(X_embedded, kernel)

    """ Perform t-SNE """
    X = stats.zscore(sampled_data, axis=0)
    X_embedded = TSNE(n_components=2, learning_rate='auto',
                  init='random', perplexity=32).fit_transform(X)
    # plt.scatter(X_embedded[:, ], X_embedded[:, 1], alpha=0.02)
    # plt.show()
    
    """ Perform Gaussian kde """
    values = X_embedded.T.copy()
    kernel = stats.gaussian_kde(values)
    # plot_kde(X_embedded, kernel)
    
    """ Resample weighted by kde estimate """
    sample_prob = kernel(values)
    norm_sample_prob = sample_prob/ np.sum(sample_prob)
    resampled_indices = np.random.choice(sampled_data.shape[0], 
                                    size=2000, 
                                    p=norm_sample_prob, replace=False)
    resampled_data = sampled_data[resampled_indices, :]

    # Save each file
    filename = subsamples_path + str(session) + '_'  + mouse_name
    np.save(filename, resampled_data)

# %% [markdown]
# ## Concatenate files

# %%
concatenated_subsampled = np.array([])
# assert len(sessions_to_process) == 319
assert len(sessions_to_process) == 318
for m, mat in enumerate(sessions_to_process):

    mouse_name = mat[0]
    session = mat[1]
    resampled_data = np.load(subsamples_path + str(session) + '_'  + mouse_name + '.npy')
    zscored_data = stats.zscore(resampled_data, axis=0, nan_policy='omit')

    """ Concatenate session """
    if len(concatenated_subsampled) == 0:
        concatenated_subsampled = zscored_data.copy()
    else:
        concatenated_subsampled = np.vstack([concatenated_subsampled, zscored_data])

# %% [markdown]
# ## Save

# %%
# np.save(open(save_path+'supersession_wavelets_paw03-19-2026', 'wb'), concatenated_subsampled)
# np.save(open(save_path+'supersession_wavelets_paw04-27-2026', 'wb'), concatenated_subsampled)
np.save(open(base_path+'session_zscored_supersession_wavelets_paw06-12-2026', 'wb'), concatenated_subsampled)
