# %% [markdown]
# # Correlate syllable probability within trial modes

# %%
prefix = '/home/ines/repositories/'
prefix = '/Users/ineslaranjeira/Documents/Repositories/'

# %%
""" 
IMPORTS
"""
import os
import numpy as np
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --Machine learning and statistics
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler,  LabelBinarizer
import umap
from scipy import stats
from sklearn.decomposition import PCA
from statsmodels.distributions.empirical_distribution import ECDF
from sklearn.utils import resample

# Image processing
from scipy import ndimage as ndi
from skimage.segmentation import watershed
from skimage.feature import peak_local_max
import cv2

# Get my functions
functions_path =  prefix + 'representation_learning_variability/Models/Sub-trial//2_fit_models/'
os.chdir(functions_path)
from preprocessing_functions import idxs_from_files
functions_path =  prefix + 'representation_learning_variability/Models/Sub-trial/4_analyses/5_clustering_analyses/'
os.chdir(functions_path)
# from clustering_functions import calculate_entropy
functions_path =  prefix + 'representation_learning_variability/Models/Sub-trial//3_postprocess_results/'
os.chdir(functions_path)
from plotting_functions import create_grouped_gradient_palette
from one.api import ONE
one = ONE(mode='remote')

# %%
data_path = prefix + 'representation_learning_variability/paper-individuality/fig1_segmentation/'
states_file = pd.read_parquet(data_path+'states_trial_type_09-29-2025')

# %%
data_path = prefix + 'representation_learning_variability/paper-individuality/clustering/'
trial_modes = pd.read_parquet(data_path+'17_trial_waterclust')
# trial_modes = pd.read_parquet(data_path+'9_cluster_per_trial')

# %%
trial_modes['trial_id'] = trial_modes['sample'].str.split().str[1:2].str.join('')
trial_modes['trial_id'] = trial_modes['trial_id'] .astype(float)

# %%
states_file = states_file.merge(trial_modes[['trial_id', 'session', 'trial_cluster']], on=['trial_id', 'session'])

# %% [markdown]
# # Trials shuffled

# %%
states_file['shuffle_trial_id'] = np.random.permutation(states_file['trial_id'].values)

group_cols = ['mouse_name', 'session', 'trial_id', 'broader_label']

data = (states_file
        .groupby(group_cols + ['most_likely_states'])
        .size()
        .reset_index(name='count'))

# Convert counts to fractions within each group
data['usage'] = (
    data['count'] /
    data.groupby(group_cols)['count'].transform('sum'))

data = data.sort_values('broader_label', 
                        key=lambda s: s.apply(['Pre-quiescence', 'Quiescence',
                                                'Choice', 'ITI'].index), ignore_index=True
                                                ).sort_values(by=['mouse_name', 'session', 
                                                                    'most_likely_states']).reset_index()
group_cols = ['session', 'trial_id']
pivoted_data = pd.pivot_table(data, values='usage', index=group_cols, 
                                columns=['most_likely_states', 'broader_label']).reset_index().fillna(0)

X = pivoted_data.drop(columns=['session', 'trial_id'])
corr = X.corr()
plt.figure(figsize=(6, 6))
plt.imshow(corr, vmin=-1, vmax=1)
plt.colorbar(label='Correlation')
plt.xlabel('Syllable x epoch')
plt.title('Syllable usage correlation')
plt.tight_layout()
n_syll = 32
for k in range(1, 4):
    plt.axhline(k * n_syll - 0.5)
    plt.axvline(k * n_syll - 0.5)
plt.show()
rho_shuffle = np.nanmean(np.abs(np.array(corr)))
# Out:
# /var/folders/nt/d2j3zp9d1xzb8wgfrw81j0c40000gn/T/ipykernel_65281/1535483934.py:24: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X = pivoted_data.drop(columns=['session', 'trial_id'])

# %%
group_cols = ['mouse_name', 'session', 'trial_id', 'broader_label', 'trial_cluster']

data = (states_file
        .groupby(group_cols + ['most_likely_states'])
        .size()
        .reset_index(name='count'))

# Convert counts to fractions within each group
data['usage'] = (
    data['count'] /
    data.groupby(group_cols)['count'].transform('sum'))

data = data.sort_values('broader_label', 
                        key=lambda s: s.apply(['Pre-quiescence', 'Quiescence',
                                                'Choice', 'ITI'].index), ignore_index=True
                                                ).sort_values(by=['mouse_name', 'session', 
                                                                    'trial_cluster', 
                                                                    'most_likely_states']).reset_index()
group_cols = ['session', 'trial_cluster', 'trial_id']
pivoted_data = pd.pivot_table(data, values='usage', index=group_cols, 
                                columns=['most_likely_states', 'broader_label']).reset_index().fillna(0)

# for m, mode in enumerate(np.arange(0, 17, 1)):
for m, mode in enumerate(np.arange(0, 10, 1)):

    if m == 0:
        X = pivoted_data.drop(columns=['session', 'trial_cluster', 'trial_id'])
        corr = X.corr()
    else:
        X = pivoted_data.loc[pivoted_data['trial_cluster']==mode].drop(columns=['session',
                                                                                'trial_cluster', 'trial_id'])
        corr = X.corr()

    plt.figure(figsize=(6, 6))
    plt.imshow(corr, vmin=-1, vmax=1)
    plt.colorbar(label='Correlation')
    plt.title('Trial mode '+str(m))
    plt.xlabel('Syllable usage correlation')
    plt.tight_layout()
    n_syll = 32
    for k in range(1, 4):
        plt.axhline(k * n_syll - 0.5)
        plt.axvline(k * n_syll - 0.5)
    plt.show()

    rho = np.nanmean(np.abs(np.array(corr)))
    if m == 0:
        rhos = [rho]
    else:
        rhos = np.concatenate([rhos, [rho]])
# Out:
# /var/folders/nt/d2j3zp9d1xzb8wgfrw81j0c40000gn/T/ipykernel_65574/655759486.py:27: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X = pivoted_data.drop(columns=['session', 'trial_cluster', 'trial_id'])
# /var/folders/nt/d2j3zp9d1xzb8wgfrw81j0c40000gn/T/ipykernel_65574/655759486.py:30: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X = pivoted_data.loc[pivoted_data['trial_cluster']==mode].drop(columns=['session',

# %%
plt.plot(rhos)

# %%
np.shape(np.array(corr))
# Out:
# (128, 128)

# %%
for m, mode in enumerate(np.arange(0, 17, 1)):
    if m == 0:
        X = pivoted_data.drop(columns='session')
        corr = X.corr()
    else:
        X = pivoted_data.loc[pivoted_data['trial_cluster']==mode].drop(columns='session')
        corr = X.corr()

    plt.figure(figsize=(6, 6))
    plt.imshow(corr, vmin=-1, vmax=1)
    plt.colorbar(label='Correlation')
    plt.title('Trial mode '+str(m))
    plt.xlabel('Syllable usage correlation')
    plt.tight_layout()
    n_syll = 32
    for k in range(1, 4):
        plt.axhline(k * n_syll - 0.5)
        plt.axvline(k * n_syll - 0.5)
    plt.show()
# Out:
# /var/folders/nt/d2j3zp9d1xzb8wgfrw81j0c40000gn/T/ipykernel_64725/3258297333.py:3: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X = pivoted_data.drop(columns='session')
# /var/folders/nt/d2j3zp9d1xzb8wgfrw81j0c40000gn/T/ipykernel_64725/3258297333.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X = pivoted_data.loc[pivoted_data['trial_cluster']==mode].drop(columns='session')

# %%
group_cols = ['mouse_name', 'session', 'trial_id', 'broader_label']

data = (states_file
        .groupby(group_cols + ['most_likely_states'])
        .size()
        .reset_index(name='count'))

# Convert counts to fractions within each group
data['usage'] = (
    data['count'] /
    data.groupby(group_cols)['count'].transform('sum'))

data = data.sort_values('broader_label', 
                        key=lambda s: s.apply(['Pre-quiescence', 'Quiescence',
                                                'Choice', 'ITI'].index), ignore_index=True
                                                ).sort_values(by=['mouse_name', 'session', 
                                                                  'most_likely_states']).reset_index()
group_cols = ['mouse_name', 'session']
group_cols = ['session']
pivoted_data = pd.pivot_table(data, values='usage', index=group_cols, columns=['most_likely_states', 'broader_label']).reset_index().fillna(0)

X = pivoted_data.drop(columns='session')
corr = X.corr()

# %%
plt.figure(figsize=(6, 6))
plt.imshow(corr, vmin=-1, vmax=1)
plt.colorbar(label='Correlation')
plt.title('Syllable usage correlation (epoch × syllable)')
plt.tight_layout()
n_syll = 32
for k in range(1, 4):
    plt.axhline(k * n_syll - 0.5)
    plt.axvline(k * n_syll - 0.5)

plt.show()

# %%
iter = 1

all_corrs = {}
for i in range(iter):
    states_file['shuffle_trial_id'] = np.random.permutation(states_file['trial_id'].values)
    group_cols = ['mouse_name', 'session', 'shuffle_trial_id', 'broader_label']
    data = (states_file
            .groupby(group_cols + ['most_likely_states'])
            .size()
            .reset_index(name='count'))
    # Convert counts to fractions within each group
    data['usage'] = (
        data['count'] /
        data.groupby(group_cols)['count'].transform('sum'))

    data = data.sort_values('broader_label', 
                            key=lambda s: s.apply(['Pre-quiescence', 'Quiescence',
                                                    'Choice', 'ITI'].index), ignore_index=True
                                                    ).sort_values(by=['mouse_name', 'session', 
                                                                    'most_likely_states']).reset_index()
    group_cols = ['session', 'trial_id']
    pivoted_data = pd.pivot_table(data, values='usage', index=group_cols, 
                                  columns=['most_likely_states', 
                                           'broader_label']).reset_index().fillna(0)
    X = pivoted_data.drop(columns='session')
    corr = X.corr()
    if i == 0:
        all_corrs = np.array(corr)
    else:
        all_corrs = np.concatenate([all_corrs, np.array(corr)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[190], line 22
#      16 data = data.sort_values('broader_label',
#      17                         key=lambda s: s.apply(['Pre-quiescence', 'Quiescence',
#      18                                                 'Choice', 'ITI'].index), ignore_index=True
#      19                                                 ).sort_values(by=['mouse_name', 'session',
#      20                                                                 'most_likely_states']).reset_index()
#      21 group_cols = ['session', 'trial_id']
# ---> 22 pivoted_data = pd.pivot_table(data, values='usage', index=group_cols,
#      23                               columns=['most_likely_states',
#      24                                        'broader_label']).reset_index().fillna(0)
#      25 X = pivoted_data.drop(columns='session')
#      26 corr = X.corr()
# ...

# %%
x = pivoted_data.drop(columns=['session', 'shuffle_trial_id']).to_numpy()
xx = x.reshape(len(x), 32, 4)
# Out:
# /var/folders/nt/d2j3zp9d1xzb8wgfrw81j0c40000gn/T/ipykernel_60627/2590320391.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   x = pivoted_data.drop(columns=['session', 'trial_id']).to_numpy()

# %%
def cross_epoch_corr_numpy(X):
    Xc = X - X.mean(axis=1, keepdims=True)
    Xn = Xc / (Xc.std(axis=1, keepdims=True) + 1e-8)
    C  = np.einsum('tes, tfs -> tef', Xn, Xn) / Xn.shape[1]
    return C

C = np.abs(cross_epoch_corr_numpy(xx))
mask = ~np.eye(32, dtype=bool)
rho = C[:, mask].mean(axis=1)

# %%
np.shape(rho)
# Out:
# (135785,)

# %%
plt.hist(rho)
# Out:
# (array([1.5400e+02, 5.1700e+02, 3.8530e+03, 2.2864e+04, 4.8244e+04,
#         3.9731e+04, 1.6155e+04, 3.7420e+03, 4.8500e+02, 4.0000e+01]),
#  array([0.00289819, 0.00694466, 0.01099114, 0.01503761, 0.01908409,
#         0.02313057, 0.02717704, 0.03122352, 0.03527   , 0.03931647,
#         0.04336295]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(rho)
# Out:
# (array([1.5400e+02, 5.1700e+02, 3.8530e+03, 2.2864e+04, 4.8244e+04,
#         3.9731e+04, 1.6155e+04, 3.7420e+03, 4.8500e+02, 4.0000e+01]),
#  array([0.00289819, 0.00694466, 0.01099114, 0.01503761, 0.01908409,
#         0.02313057, 0.02717704, 0.03122352, 0.03527   , 0.03931647,
#         0.04336295]),
#  <BarContainer object of 10 artists>)

# %%
plt.imshow(mean_mat)

# %%
mean_mat = C.mean(axis=0)

# %%
plt.figure(figsize=(6, 6))
plt.imshow(mean_mat, vmin=-1, vmax=1)
plt.colorbar(label='Correlation')
plt.title('Mean syllable usage correlation - trials shuffled')
plt.tight_layout()
n_syll = 32
for k in range(1, 4):
    plt.axhline(k * n_syll - 0.5)
    plt.axvline(k * n_syll - 0.5)

plt.show()

# %%
epoch_order = ['Pre-quiescence', 'Quiescence', 'Choice', 'ITI']
syll_order = np.arange(0, 32, 1.)

corr = corr.reindex(
    index=pd.MultiIndex.from_product([epoch_order, syll_order]),
    columns=pd.MultiIndex.from_product([epoch_order, syll_order])
)

# %% [markdown]
# # TODO: for each pair of epochs, correlate probability of each syllable (can separate or keep together in same correlation?);
# then shuffle trial labels (not epoch labels!). there should be less correlation? this is independent of trial mode label
#
# can also try to do with epoch labels, but then this is a different test.

# %% [markdown]
# ## Get sequences per epoch

# %%
design_df = all_sequences.pivot(index=['sample', 'trial_type', 'mouse_name'], columns=['broader_label'], values='binned_sequence').reset_index().dropna()
var_names = design_df.keys()[-4:]

# %%
epoch_sequences = np.vstack(all_sequences['binned_sequence'])  # Transpose to get the right shape

use_mat = pd.DataFrame(epoch_sequences)
use_mat['epoch'] = pd.factorize(all_sequences['broader_label'])[0]
named_labels = all_sequences['broader_label']

# %% [markdown]
# ## Separate states per variable (one-hot encoding)

# %%
use_sequences = epoch_sequences

use_states = int(max(np.unique(epoch_sequences)))+1
timesteps = np.shape(use_sequences)[1]
binarized = np.zeros((np.shape(use_sequences)[0], timesteps*use_states))

for t in range(timesteps):
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(range(use_states))
    encoded_arr = label_binarizer.transform(use_sequences[:, t])
    binarized[:, t*use_states:(t+1)*use_states] = encoded_arr

# %%
final_matrix = binarized.copy()

# %%
plt.figure(figsize=(10, 4))
plt.imshow(np.array(final_matrix), aspect='auto', cmap='viridis', interpolation='none')
plt.xticks(np.arange(0, np.shape(final_matrix)[1], 160), np.arange(0, np.shape(final_matrix)[1], 160))
# Out:
# ([<matplotlib.axis.XTick at 0x7fdda75af850>,
# ...
#  [Text(0, 0, '0'), Text(160, 0, '160')])

# %% [markdown]
# # PCA

# %%
n_components = 300
# Step 1: Reduce dimensions with PCA
pca = PCA(n_components)  # Reduce to 50 dimensions
scaler = StandardScaler()
standardized_X = scaler.fit_transform(final_matrix)
X_pca = pca.fit_transform(standardized_X)
# X_pca = pca.fit_transform(final_matrix)

# %%
# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratio)

# Plot explained variance
plt.figure(figsize=(8, 5))
plt.plot(range(1, n_components+1), explained_variance_ratio, marker='o', label='Individual')
plt.plot(range(1, n_components+1), cumulative_variance, marker='s', label='Cumulative', linestyle='--')
plt.xlabel("Number of Principal Components")
plt.ylabel("Variance Explained")
plt.title("Explained Variance by PCA")
# Out:
# Text(0.5, 1.0, 'Explained Variance by PCA')

# %% [markdown]
# # UMAP

# %%
ori_X = X_pca.copy()
# ori_X = final_matrix.copy()

# %%
reducer = umap.UMAP(random_state= 42, n_components=2)
# reducer = umap.UMAP(n_components=2)

embedding = reducer.fit_transform(ori_X)
# embedding = reducer.fit_transform(X_pca)
embedding.shape
# Out:
# /opt/anaconda3/envs/iblenv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/anaconda3/envs/iblenv/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /opt/anaconda3/envs/iblenv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:328: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /opt/anaconda3/envs/iblenv/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:453: UserWarning: Exited at iteration 53 with accuracies
# [6.48877635e-07 1.66583085e-06 2.38764050e-04 9.93591434e-05]
# not reaching the requested tolerance 1.8924474716186523e-06.
# ...

# %%
from skimage.filters import threshold_otsu
from skimage.filters import gaussian
from skimage.segmentation import find_boundaries
from skimage.morphology import disk

# %%
def plot_kde(X_embedded, kernel, xmin, xmax, ymin, ymax, res):
    X, Y = np.mgrid[xmin:xmax:res, ymin:ymax:res]
    positions = np.vstack([X.ravel(), Y.ravel()])
    Z = np.reshape(kernel(positions).T, X.shape)

    fig, ax = plt.subplots(figsize=(6, 5))
    ax.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,
            extent=[xmin, xmax, ymin, ymax], aspect='auto')
    ax.plot(X_embedded[:, 0], X_embedded[:, 1], 'k.', 
            markersize=.1, alpha=.1)
    ax.set_xlim([xmin, xmax])
    ax.set_ylim([ymin, ymax])
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')

    plt.show()

    return Z

def points_to_pixels(points, xmin, xmax, ymin, ymax, nx, ny):
    px = ((points[:, 0] - xmin) / (xmax - xmin) * (nx - 1)).astype(int)
    py = ((points[:, 1] - ymin) / (ymax - ymin) * (ny - 1)).astype(int)

    px = np.clip(px, 0, nx - 1)
    py = np.clip(py, 0, ny - 1)

    return px, py

# %%
""" Perform Gaussian kde """
values = embedding.T.copy()
kernel = stats.gaussian_kde(values)

xmin = -7
xmax = 13
ymin=-5
ymax=11
Z = plot_kde(embedding, kernel, xmin, xmax, ymin, ymax, res=300j)

# %%
image = Z.copy()
# image = gaussian(image, sigma=.5)

binary = image > np.percentile(image, 50)
binary = ndi.binary_fill_holes(binary)

coords = peak_local_max(
    image,
    footprint=disk(1),
    min_distance=1,
    labels=binary)
markers = np.zeros(image.shape, dtype=int)
markers[tuple(coords.T)] = np.arange(1, len(coords) + 1)

labels = watershed(-image, markers, mask=binary)

boundaries = find_boundaries(labels, mode="outer")

fig, ax = plt.subplots(1, 4, figsize=(14, 4))
ax[0].imshow(np.rot90(Z))
ax[0].set_title("KDE image")
ax[1].imshow(np.rot90(binary))
ax[1].set_title("Binary mask")
ax[2].imshow(np.rot90(labels), cmap="tab20")
ax[2].set_title("Watershed")
ax[3].imshow(np.rot90(image))
ax[3].imshow(np.rot90(boundaries), cmap="Reds", alpha=0.2)
ax[3].set_title("Watershed")
for a in ax:
    a.axis("off")
plt.show()

# %%
epoch_number = pd.factorize(named_labels)[0]
cmap = plt.get_cmap("tab10")
clusters = np.unique(epoch_number)
color_dict = {
    k: cmap(k % cmap.N)   # exact tab20 color
    for k in clusters}
scatter_colors = np.array([color_dict[k] for k in epoch_number])
# plt.scatter(
#     embedding[:, 0],
#     embedding[:, 1],
#     color=scatter_colors, #c=point_labels,
#     cmap="tab20",
#     s=2, alpha=.1)
# plt.imshow(np.rot90(boundaries), cmap=plt.cm.gist_earth_r,
#         extent=[xmin, xmax, ymin, ymax], aspect='auto')
# plt.axis("off")
# plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
xmin = -15
xmax = -5
ymin=5
ymax=10
ax.scatter(embedding[:, 0], embedding[:, 1], color=scatter_colors, alpha=.5, s=.1) #'k.',
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
ax.set_xlabel('UMAP 1')
ax.set_ylabel('UMAP 2')

plt.show()

# %%
data_path = prefix + 'representation_learning_variability/paper-individuality/clustering/'
np.save(data_path+'epoch_umap_no_standardiz', embedding)
# embedding.to_parquet(data_path+'epoch_umap_no_standardiz',compression='gzip')
