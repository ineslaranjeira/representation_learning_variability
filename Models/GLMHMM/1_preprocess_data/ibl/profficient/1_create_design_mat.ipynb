# %% [markdown]
# ### Create design matrix with IBL mice
# #### Normalize data across all animals and all bins

# %%
"""
IMPORTS
"""
import numpy as np
from oneibl.onelight import ONE
import numpy.random as npr
import json
from sklearn import preprocessing
from collections import defaultdict
import wget
from zipfile import ZipFile
import os
import pandas as pd
from preprocessing_utils_session_ines import get_animal_name, load_animal_list, load_animal_eid_dict, \
    get_all_unnormalized_data_this_session, create_train_test_sessions

npr.seed(65)

# %%
"""
Load data
"""
data_dir = '/home/ines/repositories/representation_learning_variability/DATA/GLMHMM/'
#data_dir = '/Users/ineslaranjeira/Documents/Repositories/representation_learning_variability/DATA/GLMHMM/'
#data_dir = '/home/ines/repositories/learning_variability/HMMs/Zoes_model/data/ibl/partially_processed/'
# Load animal list/results of partial processing:
animal_list = load_animal_list(
    data_dir + 'animal_list_prof.npz')
animal_eid_dict = load_animal_eid_dict(
    data_dir + 'animal_eid_dict_prof.json')

# %%
"""
Create folders to save processed data
"""
#data_dir = '/home/ines/repositories/learning_variability/HMMs/Zoes_model/data/ibl-behavioral-data-Dec-2019/'
# Create directories for saving data:
processed_ibl_data_path = data_dir + "data_for_cluster/"
if not os.path.exists(processed_ibl_data_path):
    os.makedirs(processed_ibl_data_path)
# Also create a subdirectory for storing each animal's data:
if not os.path.exists(processed_ibl_data_path + "data_by_animal"):
    os.makedirs(processed_ibl_data_path + "data_by_animal")

# %%
# Require that each animal has at least 10 sessions (=2700 trials) of data:
req_num_sessions = 20  # 30*90 = 2700
total_sessions = 0
for animal in animal_list:
    num_sessions = len(animal_eid_dict[animal])
    print(num_sessions)
    if num_sessions < req_num_sessions:
        animal_list = np.delete(animal_list,
                                np.where(animal_list == animal))
    else:
        total_sessions = total_sessions + num_sessions
# Out:
# 31
# 70
# 30
# 37
# 35
# 37
# 31
# 54
# 37
# 58
# 72
# 61
# 74
# 61
# 60
# 44
# 62
# 57
# 32
# 40
# 34
# 30
# 36
# 38
# 43
# 32
# 42
# 38
# 68
# 75
# 51
# 52
# 36
# 40
# 83
# 78
# 76
# 67
# 30
# 139
# 134
# 128
# 133
# 36
# 60
# 40
# 43
# 32
# 30
# 34
# 37
# 70
# 39
# 60
# 31
# 33
# 35
# 40
# 36
# 46
# 42
# 40
# 45
# 80
# 66
# 61
# 33
# 49
# 43
# 32
# 36
# 56
# 46
# 32
# 58
# 43
# 93
# 82
# 96
# 86
# 48
# 49
# 42
# 42
# 68
# 89
# 65
# 40
# 40
# 32
# 60
# 43
# 49
# 35
# 43
# 54
# 36
# 31
# 39
# 37
# 37
# 33
# 35
# 42
# 42
# 83
# 100
# 37
# 53
# 53
# 48
# 40
# 43
# 33
# 32
# 55
# 53
# 127
# 36
# 119
# 102
# 47
# 38
# 31
# 73
# 39
# 157
# 112
# 71
# 36
# 32
# 31
# 48
# 50
# 35
# 58
# 37
# 36
# 30
# 39
# 35
# 51
# 50
# 113
# 51
# 59
# 30
# 37
# 51
# 53
# 50
# 65
# 60
# 45
# 75
# 34
# 31
# 34
# 31
# 46
# 77
# 78
# 98
# 77
# 54
# 55
# 52
# 32
# 34
# 35
# 30
# 46
# 32
# 53
# 37
# 43
# 86
# 85
# 85
# 96

# %%
all_trials.task_protocol.unique()
# Out:
# array(['_iblrig_tasks_biasedChoiceWorld6.3.1',
#        '_iblrig_tasks_trainingChoiceWorld6.3.1',
#        '_iblrig_tasks_biasedChoiceWorld6.2.5',
#        '_iblrig_tasks_ephysChoiceWorld6.2.5',
#        '_iblrig_tasks_ephysChoiceWorld6.4.0',
#        '_iblrig_tasks_biasedChoiceWorld6.4.0',
#        '_iblrig_tasks_trainingChoiceWorld6.2.5',
#        '_iblrig_tasks_biasedChoiceWorld6.2.4',
#        '_iblrig_tasks_trainingChoiceWorld6.1.3',
#        '_iblrig_tasks_trainingChoiceWorld6.2.1',
#        '_iblrig_tasks_trainingChoiceWorld6.2.0',
#        '_iblrig_tasks_biasedChoiceWorld6.2.1',
#        '_iblrig_tasks_trainingChoiceWorld6.2.4',
#        '_iblrig_tasks_trainingChoiceWorld6.4.0',
#        '_iblrig_tasks_biasedChoiceWorld4.1.3',
#        '_iblrig_tasks_biasedChoiceWorld5.2.7',
#        '_iblrig_tasks_biasedChoiceWorld5.2.5',
#        '_iblrig_tasks_biasedChoiceWorld4.0.1',
#        '_iblrig_tasks_trainingChoiceWorld4.0.1',
#        '_iblrig_tasks_biasedChoiceWorld5.2.9',
#        '_iblrig_tasks_biasedChoiceWorld5.1.2',
#        '_iblrig_tasks_biasedChoiceWorld5.2.3',
#        '_iblrig_tasks_biasedChoiceWorld3.8.0',
#        '_iblrig_tasks_biasedChoiceWorld3.7.6',
#        '_iblrig_tasks_trainingChoiceWorld3.7.6',
#        '_iblrig_tasks_biasedChoiceWorld3.8.1',
#        '_iblrig_tasks_trainingChoiceWorld4.1.2',
#        '_iblrig_tasks_biasedChoiceWorld4.1.2',
#        '_iblrig_tasks_biasedChoiceWorld5.2.1',
#        '_iblrig_tasks_biasedChoiceWorld6.0.5',
#        '_iblrig_tasks_biasedChoiceWorld6.0.6',
#        '_iblrig_tasks_ephysChoiceWorld6.0.6',
#        '_iblrig_tasks_ephysChoiceWorld6.1.1',
#        '_iblrig_tasks_biasedChoiceWorld5.3.0',
#        '_iblrig_tasks_ephysChoiceWorld5.3.0',
#        '_iblrig_tasks_biasedChoiceWorld6.1.3',
#        '_iblrig_tasks_trainingChoiceWorld5.2.5',
#        '_iblrig_tasks_biasedChoiceWorld6.1.2',
#        '_iblrig_tasks_biasedChoiceWorld5.2.2',
#        '_iblrig_tasks_ephysChoiceWorld6.1.3',
#        '_iblrig_tasks_biasedChoiceWorld5.3.1',
#        '_iblrig_tasks_biasedChoiceWorld5.0.0',
#        '_iblrig_tasks_trainingChoiceWorld4.1.3',
#        '_iblrig_tasks_trainingChoiceWorld5.0.0',
#        '_iblrig_tasks_trainingChoiceWorld5.2.9',
#        '_iblrig_tasks_biasedChoiceWorld5.1.0',
#        '_iblrig_tasks_ephysChoiceWorld6.1.2',
#        '_iblrig_tasks_trainingChoiceWorld5.3.0',
#        '_iblrig_tasks_biasedChoiceWorld6.0.2',
#        '_iblrig_tasks_biasedChoiceWorld6.0.3',
#        '_iblrig_tasks_biasedChoiceWorld6.4.1',
#        '_iblrig_tasks_ephysChoiceWorld6.4.1',
#        '_iblrig_tasks_trainingChoiceWorld6.4.1',
#        '_iblrig_tasks_ephysChoiceWorld6.4.2',
#        '_iblrig_tasks_biasedChoiceWorld6.4.2',
#        '_iblrig_tasks_biasedChoiceWorld4.1.0',
#        '_iblrig_tasks_trainingChoiceWorld4.1.0',
#        '_iblrig_tasks_trainingChoiceWorld6.4.2',
#        '_iblrig_tasks_trainingChoiceWorld3.7.2',
#        '_iblrig_tasks_biasedChoiceWorld5.2.0',
#        '_iblrig_tasks_trainingChoiceWorld3.8.1',
#        '_iblrig_tasks_trainingChoiceWorld3.8.0',
#        '_iblrig_tasks_trainingChoiceWorld5.1.2',
#        '_iblrig_tasks_biasedChoiceWorld3.7.3',
#        '_iblrig_tasks_biasedChoiceWorld3.7.2',
#        '_iblrig_tasks_biasedChoiceWorld3.7.4',
#        '_iblrig_tasks_biasedChoiceWorld3.7.1',
#        '_iblrig_tasks_trainingChoiceWorld5.2.2',
#        '_iblrig_tasks_trainingChoiceWorld5.2.7',
#        '_iblrig_tasks_trainingChoiceWorld5.2.3',
#        '_iblrig_tasks_trainingChoiceWorld5.2.1',
#        '_iblrig_tasks_biasedChoiceWorld6.0.0',
#        '_iblrig_tasks_ephysChoiceWorld6.0.3',
#        '_iblrig_tasks_ephysChoiceWorld5.2.9',
#        '_iblrig_tasks_trainingChoiceWorld6.0.6',
#        '_iblrig_tasks_trainingChoiceWorld6.0.5',
#        '_iblrig_tasks_trainingChoiceWorld6.2.3',
#        '_iblrig_tasks_trainingChoiceWorld6.0.3',
#        '_iblrig_tasks_prestim_opto6.2.5',
#        '_iblrig_tasks_biasedChoiceWorld6.2.3',
#        '_iblrig_tasks_biasedChoiceWorld6.3.0',
#        '_iblrig_tasks_optoFloraChW6.2.5',
#        '_iblrig_tasks_trainingChoiceWorld6.3.0',
#        '_iblrig_tasks_ephyskarolinaChoiceWorld6.4.2',
#        '_iblrig_tasks_biasedkarolinaChoiceWorld6.4.2',
#        '_iblrig_tasks_ksocha_ephysOptoChoiceWorld6.4.2',
#        '_iblrig_tasks_biasedChoiceWorld',
#        '_iblrig_tasks_biasedChoiceWorld6.5.2',
#        '_iblrig_tasks_biasedChoiceWorld6.5.0',
#        '_iblrig_tasks_ephysChoiceWorld',
#        '_iblrig_tasks_trainingChoiceWorld',
#        '_iblrig_ksocha_opto_biasedChoiceWorld6.5.3',
#        '_iblrig_tasks_biasedChoiceWorld6.5.3',
#        '_iblrig_tasks_ephysChoiceWorld6.5.3',
#        '_iblrig_tasks_trainingChoiceWorld6.5.3',
#        '_iblrig_tasks_biasedChoiceWorld6.6.1',
#        '_iblrig_ksocha_opto_biasedChoiceWorld6.6.1',
#        '_iblrig_tasks_biasedChoiceWorld6.6.2',
#        '_iblrig_tasks_trainingChoiceWorld6.6.1',
#        '_iblrig_tasks_trainingChoiceWorld5.2.0',
#        '_iblrig_tasks_trainingChoiceWorld6.2.2',
#        '_iblrig_tasks_biasedChoiceWorld5.1.3',
#        '_iblrig_tasks_biasedChoiceWorld5.1.1',
#        '_iblrig_tasks_ephysChoiceWorld6.2.4',
#        '_iblrig_tasks_trainingChoiceWorld5.3.1',
#        '_iblrig_tasks_ephysChoiceWorld6.6.1',
#        '_iblrig_tasks_biasedChoiceWorld6.5.1',
#        '_iblrig_tasks_biasedChoiceWorld7.2.0',
#        '_iblrig_tasks_biasedChoiceWorld3.7.0',
#        '_iblrig_tasks_trainingChoiceWorld3.7.0',
#        '_iblrig_tasks_biasedChoiceWorldRPE',
#        '_iblrig_tasks_trainingChoiceWorld5.1.3',
#        '_iblrig_tasks_ephysChoiceWorld6.2.3',
#        '_iblrig_tasks_ephysChoiceWorld6.2.0',
#        '_iblrig_tasks_biasedChoiceWorld6.2.0',
#        '_iblrig_tasks_biasedChoiceWorld6.2.2',
#        '_iblrig_tasks_trainingChoiceWorld3.7.3',
#        '_iblrig_tasks_trainingChoiceWorld3.7.1'], dtype=object)

# %%
trials_dir = '/home/ines/repositories/representation_learning_variability/DATA/'
#trials_dir = '/Users/ineslaranjeira/Documents/Repositories/representation_learning_variability/DATA/'
all_trials = pd.read_csv(trials_dir + "proficient_one.csv")

# %%
# Identify idx in master array where each animal-bin's data starts and ends:
animal_start_idx = {}
animal_end_idx = {}

missing_data = []

final_animal_eid_dict = defaultdict(list)
# WORKHORSE: iterate through each animal and each animal's set of eids;
# obtain unnormalized data.  Write out each animal's data and then also
# write to master array

# Loop through animals        
for z, animal in enumerate(animal_list):
    
    animal_sessions = np.unique(all_trials.loc[all_trials['subject_nickname']==animal, 'session'])
    # Loop through animals
    sess_counter = 0
    for eid in animal_sessions:
        session_data = all_trials.loc[(all_trials['subject_nickname']==animal) & (all_trials['session']==eid)]
        animal, unnormalized_inpt, y, session, num_viols_50, rewarded = \
            get_all_unnormalized_data_this_session(
                animal, session_data)
        if num_viols_50 < 10:  # only include session if number of viols, if not, data will not be created or appended
            # Append data from different sessions of the same animal
            if sess_counter == 0:
                animal_unnormalized_inpt = np.copy(unnormalized_inpt)
                animal_y = np.copy(y)
                animal_session = session
                animal_rewarded = np.copy(rewarded)
            else:
                animal_unnormalized_inpt = np.vstack(
                    (animal_unnormalized_inpt, unnormalized_inpt))
                animal_y = np.vstack((animal_y, y))
                animal_session = np.concatenate((animal_session, session))
                animal_rewarded = np.vstack((animal_rewarded, rewarded))
            sess_counter += 1
            final_animal_eid_dict[animal].append(eid)
            
            ## Check psychometric curves!
            #un_inpt, un_y, un_bin_data = load_data(unnormalized_data)
            """
            import matplotlib.pyplot as plt
            plt.figure()
            x_stim = np.unique(unnormalized_inpt[:, 0])
            y_stim = np.zeros(len(x_stim))
            
            for s, stimulus in enumerate(x_stim):
                y_stim[s] = np.nanmean(y[np.where(unnormalized_inpt[:, 0]==stimulus), 0])
            plt.scatter(x_stim, y_stim)
            plt.title('Session' + str(sessio))
            plt.ylim([0,1])
            """
                
        else:
            print(str(animal + '_missing' + str(num_viols_50)))
            missing_data.append(animal)
        
    # Write out animal's unnormalized data matrix (all sessions concatenated):
    np.savez(
        processed_ibl_data_path + 'data_by_animal/' + animal +
            '_unnormalized.npz',
        animal_unnormalized_inpt, animal_y,
        animal_session)
    np.savez(
        processed_ibl_data_path + 'data_by_animal/' + animal +
        '_rewarded.npz',
        animal_rewarded)
    animal_session_fold_lookup = create_train_test_sessions(animal_session, num_folds=5)
    np.savez(
        processed_ibl_data_path + 'data_by_animal/' + animal +
        "_session_fold_lookup" +
        ".npz",
        animal_session_fold_lookup)
    
    assert animal_rewarded.shape[0] == animal_y.shape[0]
    #assert len(animal_bin) == len(bin_shuffled_folds)

    # Now create or append data to master array across all animals:
    if z == 0:
        master_inpt = np.copy(animal_unnormalized_inpt)
        animal_start_idx[animal] = 0
        animal_end_idx[animal] = master_inpt.shape[0] - 1
        master_y = np.copy(animal_y)
        master_session = animal_session
        master_session_fold_lookup_table = animal_session_fold_lookup
        master_rewarded = np.copy(animal_rewarded)
    else:
        animal_start_idx[animal] = master_inpt.shape[0]
        master_inpt = np.vstack((master_inpt, animal_unnormalized_inpt))
        animal_end_idx[animal] = master_inpt.shape[0] - 1
        master_y = np.vstack((master_y, animal_y))
        master_session = np.concatenate((master_session, animal_session))
        master_session_fold_lookup_table = np.vstack(
            (master_session_fold_lookup_table, animal_session_fold_lookup))  # Changed vstack into hstack
        master_rewarded = np.vstack((master_rewarded, animal_rewarded))
                
    # Write out data from across animals
    assert np.shape(master_inpt)[0] == np.shape(master_y)[
        0], "inpt and y not same length"
    assert np.shape(master_rewarded)[0] == np.shape(master_y)[
        0], "rewarded and y not same length"
    assert len(np.unique(master_session)) == \
           np.shape(master_session_fold_lookup_table)[
               0], "number of unique sessions and session fold lookup don't " \
                   "match"
    #assert len(master_inpt) == 181530, "design matrix for all IBL animals " \
    #                                   "should have shape (181530, 3)"
    #assert len(animal_list) == 37, "37 animals were studied in Ashwood et " \
    #                               "al. (2020)"
    normalized_inpt = np.copy(master_inpt)
    normalized_inpt[:, 0] = preprocessing.scale(normalized_inpt[:, 0])
    np.savez(processed_ibl_data_path + 'all_animals_concat' + '.npz',
             normalized_inpt,
             master_y, master_session)
    np.savez(
        processed_ibl_data_path + 'all_animals_concat_unnormalized' + '.npz',
        master_inpt, master_y, master_session)
    np.savez(
        processed_ibl_data_path + 'all_animals_concat_session_fold_lookup' +
        '.npz',
        master_session_fold_lookup_table)
    np.savez(processed_ibl_data_path + 'all_animals_concat_rewarded' + '.npz',
             master_rewarded)
    np.savez(processed_ibl_data_path + 'data_by_animal/' + 'animal_list.npz',
             animal_list)
    
    import json
    json = json.dumps(final_animal_eid_dict)
    f = open(processed_ibl_data_path + "final_animal_eid_dict.json", "w")
    f.write(json)
    f.close()

    # Now write out normalized data (when normalized across all animals) for
    # each animal:
    counter = 0
    for animal in animal_start_idx.keys():
        start_idx = animal_start_idx[animal]
        end_idx = animal_end_idx[animal]
        inpt = normalized_inpt[range(start_idx, end_idx + 1)]
        y = master_y[range(start_idx, end_idx + 1)]
        session = master_session[range(start_idx, end_idx + 1)]
        counter += inpt.shape[0]
        np.savez(processed_ibl_data_path + 'data_by_animal/' + animal + '_processed.npz',
                 inpt, y,
                 session)

    assert counter == master_inpt.shape[0]
# Out:
# CSHL045_missing15
# CSHL046_missing17
# CSHL051_missing15
# CSHL051_missing11
# CSHL051_missing18
# CSHL051_missing11
# CSHL051_missing15
# CSHL051_missing27
# CSHL051_missing14
# CSHL051_missing14
# CSHL051_missing30
# CSHL053_missing18
# CSHL054_missing13
# CSHL054_missing10
# CSHL054_missing35
# CSHL054_missing16
# CSHL054_missing21
# CSHL055_missing22
# CSHL055_missing19
# CSHL058_missing16
# CSHL058_missing10
# CSHL058_missing10
# CSHL058_missing19
# CSHL058_missing26
# CSHL058_missing26
# CSHL_001_missing13
# CSHL_002_missing17
# CSHL_003_missing10
# CSHL_003_missing15
# CSHL_003_missing13
# CSHL_003_missing20
# CSHL_007_missing21
# CSHL_007_missing10
# CSHL_007_missing12
# CSHL_007_missing14
# CSHL_007_missing34
# CSHL_007_missing16
# CSHL_007_missing14
# CSHL_007_missing17
# CSHL_007_missing12
# CSHL_007_missing32
# CSHL_007_missing15
# CSHL_007_missing22
# CSHL_007_missing12
# CSHL_007_missing36
# CSHL_007_missing23
# CSHL_007_missing28
# CSHL_007_missing10
# CSHL_007_missing13
# CSHL_007_missing17
# CSHL_008_missing20
# CSHL_008_missing11
# CSHL_008_missing12
# CSHL_010_missing13
# CSHL_010_missing16
# CSHL_012_missing26
# CSHL_012_missing38
# CSHL_012_missing14
# CSHL_012_missing13
# CSHL_012_missing32
# CSHL_012_missing27
# CSHL_012_missing57
# CSHL_012_missing30
# CSHL_012_missing29
# CSHL_014_missing11
# CSHL_014_missing18
# CSHL_014_missing10
# CSHL_014_missing26
# CSHL_014_missing19
# CSHL_014_missing15
# CSHL_014_missing12
# CSHL_014_missing13
# CSHL_015_missing11
# CSHL_015_missing20
# CSHL_015_missing27
# CSHL_015_missing18
# CSHL_015_missing32
# CSHL_015_missing32
# CSHL_015_missing15
# CSHL_015_missing24
# CSHL_015_missing15
# CSHL_015_missing45
# CSHL_015_missing27
# CSHL_015_missing37
# CSH_ZAD_001_missing14
# CSH_ZAD_002_missing28
# CSH_ZAD_002_missing13
# CSH_ZAD_005_missing14
# CSH_ZAD_017_missing10
# CSH_ZAD_017_missing12
# CSH_ZAD_017_missing24
# CSH_ZAD_017_missing20
# CSH_ZAD_019_missing10
# DY_001_missing13
# DY_001_missing14
# DY_001_missing11
# DY_001_missing10
# DY_001_missing24
# DY_001_missing35
# DY_001_missing11
# DY_006_missing10
# DY_007_missing19
# DY_008_missing11
# DY_008_missing10
# DY_008_missing48
# DY_008_missing35
# DY_008_missing65
# DY_008_missing17
# DY_008_missing32
# DY_008_missing16
# DY_008_missing13
# DY_008_missing23
# DY_008_missing15
# DY_008_missing21
# DY_008_missing55
# DY_008_missing25
# DY_008_missing10
# DY_008_missing40
# DY_008_missing23
# DY_008_missing17
# DY_008_missing44
# DY_008_missing19
# DY_008_missing22
# DY_008_missing23
# DY_008_missing30
# DY_008_missing42
# DY_008_missing17
# DY_008_missing17
# DY_008_missing16
# DY_008_missing40
# DY_008_missing18
# DY_008_missing31
# DY_008_missing27
# DY_008_missing26
# DY_008_missing30
# DY_008_missing18
# DY_008_missing15
# DY_008_missing15
# DY_008_missing29
# DY_008_missing36
# DY_008_missing30
# DY_008_missing14
# DY_008_missing13
# DY_008_missing14
# DY_008_missing21
# DY_008_missing16
# DY_009_missing25
# DY_009_missing12
# DY_009_missing11
# DY_009_missing10
# DY_010_missing13
# DY_010_missing13
# DY_010_missing13
# DY_010_missing15
# DY_010_missing11
# DY_010_missing13
# DY_010_missing18
# DY_010_missing10
# DY_010_missing16
# DY_010_missing22
# DY_010_missing11
# DY_010_missing24
# DY_010_missing17
# DY_010_missing35
# DY_010_missing15
# DY_010_missing13
# DY_010_missing19
# DY_011_missing16
# DY_011_missing17
# DY_011_missing10
# DY_011_missing16
# DY_011_missing10
# DY_011_missing31
# DY_011_missing13
# DY_011_missing10
# DY_011_missing11
# DY_014_missing12
# DY_014_missing12
# DY_014_missing14
# DY_014_missing12
# DY_014_missing19
# DY_014_missing12
# DY_014_missing29
# DY_018_missing24
# DY_018_missing12
# DY_018_missing21
# DY_018_missing43
# DY_018_missing15
# DY_018_missing28
# DY_018_missing13
# DY_018_missing13
# DY_018_missing17
# DY_018_missing22
# DY_018_missing15
# DY_018_missing15
# DY_018_missing17
# DY_018_missing29
# DY_018_missing10
# DY_018_missing26
# IBL-T1_missing14
# IBL-T1_missing10
# IBL-T1_missing13
# IBL-T1_missing15
# IBL-T1_missing19
# IBL-T1_missing11
# IBL-T1_missing11
# IBL-T2_missing11
# IBL-T2_missing20
# IBL-T2_missing11
# IBL-T2_missing16
# IBL-T2_missing17
# IBL-T2_missing12
# IBL-T2_missing15
# IBL-T2_missing63
# IBL-T2_missing13
# IBL-T2_missing44
# IBL-T2_missing13
# IBL-T2_missing12
# IBL-T2_missing10
# IBL-T2_missing28
# IBL-T3_missing17
# IBL-T3_missing21
# IBL-T3_missing11
# IBL-T3_missing22
# IBL-T3_missing30
# IBL-T3_missing20
# IBL-T3_missing17
# IBL-T3_missing14
# IBL-T3_missing13
# IBL-T3_missing23
# IBL-T3_missing30
# IBL-T3_missing21
# IBL-T3_missing20
# IBL-T3_missing20
# IBL-T3_missing21
# IBL-T3_missing16
# IBL-T3_missing11
# IBL-T3_missing14
# IBL-T3_missing60
# IBL-T3_missing27
# IBL-T3_missing46
# IBL-T3_missing13
# IBL-T3_missing23
# IBL-T3_missing12
# IBL-T3_missing13
# IBL-T3_missing10
# IBL-T3_missing32
# IBL-T3_missing26
# IBL-T3_missing11
# IBL-T3_missing12
# IBL-T3_missing17
# IBL-T3_missing13
# IBL-T3_missing28
# IBL-T3_missing26
# IBL-T3_missing13
# IBL-T3_missing18
# IBL-T4_missing17
# IBL-T4_missing12
# IBL-T4_missing15
# IBL-T4_missing14
# IBL-T4_missing10
# IBL-T4_missing11
# IBL-T4_missing14
# IBL-T4_missing12
# IBL-T4_missing26
# IBL-T4_missing13
# IBL-T4_missing19
# IBL-T4_missing11
# IBL-T4_missing31
# IBL_002_missing10
# IBL_10_missing13
# IBL_10_missing33
# IBL_10_missing21
# IBL_10_missing12
# IBL_10_missing19
# IBL_10_missing12
# IBL_10_missing30
# IBL_10_missing14
# IBL_10_missing13
# IBL_10_missing24
# IBL_10_missing11
# IBL_10_missing10
# IBL_10_missing10
# IBL_10_missing19
# IBL_10_missing17
# IBL_10_missing19
# IBL_10_missing10
# IBL_10_missing14
# IBL_10_missing14
# IBL_10_missing25
# IBL_10_missing31
# IBL_10_missing21
# IBL_10_missing33
# IBL_10_missing13
# IBL_10_missing36
# IBL_10_missing11
# IBL_10_missing12
# IBL_10_missing24
# IBL_10_missing14
# IBL_10_missing11
# IBL_10_missing17
# IBL_10_missing30
# IBL_10_missing11
# IBL_10_missing19
# IBL_10_missing33
# IBL_10_missing11
# IBL_10_missing11
# IBL_10_missing37
# IBL_10_missing12
# IBL_10_missing10
# IBL_10_missing16
# IBL_10_missing25
# IBL_10_missing11
# IBL_10_missing11
# IBL_10_missing11
# IBL_10_missing10
# IBL_10_missing25
# IBL_10_missing13
# IBL_10_missing20
# IBL_10_missing18
# IBL_10_missing14
# IBL_10_missing40
# IBL_10_missing11
# IBL_10_missing13
# IBL_10_missing13
# IBL_11_missing10
# IBL_11_missing34
# IBL_11_missing21
# IBL_11_missing10
# IBL_11_missing16
# IBL_11_missing32
# IBL_11_missing30
# IBL_11_missing14
# IBL_11_missing20
# IBL_11_missing22
# IBL_11_missing17
# IBL_11_missing17
# IBL_11_missing10
# IBL_11_missing32
# IBL_11_missing50
# IBL_11_missing11
# IBL_11_missing19
# IBL_11_missing16
# IBL_11_missing24
# IBL_11_missing12
# IBL_11_missing20
# IBL_11_missing21
# IBL_11_missing18
# IBL_11_missing24
# IBL_11_missing28
# IBL_11_missing13
# IBL_11_missing18
# IBL_11_missing13
# IBL_11_missing23
# IBL_11_missing26
# IBL_11_missing13
# IBL_11_missing10
# IBL_11_missing20
# IBL_11_missing32
# IBL_11_missing10
# IBL_11_missing19
# IBL_11_missing14
# IBL_11_missing14
# IBL_11_missing15
# IBL_11_missing11
# IBL_11_missing24
# IBL_34_missing11
# IBL_34_missing17
# IBL_34_missing18
# IBL_34_missing21
# IBL_34_missing27
# IBL_34_missing13
# IBL_34_missing42
# IBL_34_missing14
# IBL_34_missing14
# IBL_34_missing28
# IBL_34_missing19
# IBL_34_missing13
# IBL_34_missing28
# IBL_34_missing11
# IBL_34_missing27
# IBL_34_missing22
# IBL_34_missing13
# IBL_34_missing11
# IBL_34_missing14
# IBL_34_missing10
# IBL_34_missing24
# IBL_34_missing14
# IBL_34_missing27
# IBL_34_missing13
# IBL_34_missing23
# IBL_34_missing16
# IBL_34_missing19
# IBL_34_missing14
# IBL_34_missing15
# IBL_34_missing10
# IBL_34_missing46
# IBL_34_missing13
# IBL_34_missing13
# IBL_34_missing18
# IBL_34_missing38
# IBL_34_missing25
# IBL_34_missing25
# IBL_34_missing15
# IBL_34_missing18
# IBL_34_missing34
# IBL_34_missing23
# IBL_34_missing10
# IBL_34_missing12
# IBL_34_missing23
# IBL_34_missing20
# IBL_34_missing18
# IBL_34_missing18
# IBL_34_missing41
# IBL_34_missing18
# IBL_46_missing20
# IBL_46_missing24
# IBL_46_missing20
# IBL_46_missing11
# IBL_46_missing17
# IBL_46_missing14
# IBL_46_missing18
# IBL_46_missing17
# IBL_46_missing22
# IBL_46_missing21
# IBL_46_missing10
# IBL_46_missing13
# IBL_46_missing39
# IBL_46_missing15
# KS002_missing12
# KS003_missing16
# KS003_missing15
# KS004_missing11
# KS004_missing13
# KS004_missing25
# KS004_missing30
# KS004_missing10
# KS004_missing15
# KS004_missing17
# KS004_missing11
# KS005_missing14
# KS005_missing56
# KS005_missing25
# KS005_missing10
# KS005_missing13
# KS005_missing10
# KS005_missing18
# KS015_missing12
# KS017_missing10
# KS017_missing11
# KS017_missing12
# KS017_missing15
# KS017_missing14
# KS017_missing21
# KS017_missing17
# KS017_missing13
# KS018_missing14
# KS018_missing10
# KS018_missing10
# KS018_missing13
# KS018_missing10
# KS018_missing15
# KS018_missing14
# KS019_missing41
# KS019_missing109
# KS021_missing37
# KS021_missing34
# KS024_missing22
# KS051_missing17
# KS051_missing13
# KS051_missing10
# KS051_missing15
# KS053_missing19
# KS053_missing19
# KS053_missing16
# KS053_missing14
# KS056_missing48
# KS056_missing77
# KS056_missing24
# KS056_missing29
# KS056_missing16
# KS056_missing26
# KS056_missing12
# KS056_missing33
# KS056_missing62
# KS056_missing27
# KS056_missing41
# KS056_missing44
# KS078_missing14
# KS078_missing46
# KS078_missing18
# KS078_missing18
# KS078_missing14
# KS078_missing18
# KS078_missing47
# KS078_missing15
# KS078_missing20
# KS078_missing15
# KS079_missing21
# KS079_missing15
# KS079_missing28
# KS079_missing38
# KS079_missing13
# KS079_missing26
# KS079_missing12
# KS079_missing14
# KS079_missing14
# KS079_missing35
# KS079_missing46
# KS079_missing40
# KS079_missing11
# KS079_missing26
# KS079_missing25
# KS079_missing15
# KS079_missing32
# KS079_missing14
# KS079_missing17
# KS079_missing16
# KS079_missing17
# KS079_missing20
# KS079_missing22
# KS079_missing43
# KS079_missing25
# KS079_missing13
# KS079_missing23
# KS079_missing18
# KS079_missing16
# KS079_missing12
# KS079_missing32
# KS079_missing11
# KS079_missing32
# KS079_missing72
# KS079_missing93
# KS079_missing12
# KS079_missing32
# KS079_missing33
# KS079_missing16
# KS079_missing26
# KS079_missing38
# KS079_missing23
# KS079_missing44
# KS079_missing33
# KS079_missing20
# KS079_missing12
# KS079_missing27
# KS079_missing15
# KS079_missing11
# KS079_missing18
# KS079_missing39
# KS079_missing15
# KS079_missing39
# KS079_missing10
# KS080_missing13
# KS080_missing13
# KS080_missing21
# KS080_missing10
# KS080_missing12
# KS080_missing25
# KS083_missing15
# KS083_missing13
# KS083_missing14
# KS083_missing16
# KS084_missing32
# KS084_missing16
# KS084_missing14
# KS085_missing36
# KS085_missing20
# KS085_missing15
# KS086_missing23
# KS086_missing26
# KS086_missing16
# KS090_missing10
# KS090_missing14
# KS090_missing34
# KS090_missing27
# KS090_missing172
# KS092_missing11
# KS092_missing11
# KS092_missing11
# KS093_missing30
# KS093_missing20
# KS093_missing18
# KS093_missing17
# KS093_missing21
# KS093_missing13
# KS093_missing19
# KS095_missing10
# LTC03_missing21
# LTC03_missing40
# LTC03_missing10
# LTC03_missing10
# LTC03_missing40
# LTC03_missing13
# LTC03_missing40
# LTC03_missing18
# NR_0005_missing12
# NYU-01_missing10
# NYU-01_missing28
# NYU-01_missing32
# NYU-01_missing18
# NYU-01_missing14
# NYU-01_missing42
# NYU-01_missing17
# NYU-01_missing34
# NYU-01_missing22
# NYU-01_missing11
# NYU-01_missing48
# NYU-01_missing21
# NYU-01_missing23
# NYU-01_missing36
# NYU-01_missing15
# NYU-01_missing27
# NYU-01_missing43
# NYU-01_missing50
# NYU-01_missing19
# NYU-01_missing11
# NYU-01_missing58
# NYU-01_missing31
# NYU-01_missing22
# NYU-02_missing17
# NYU-02_missing20
# NYU-02_missing12
# NYU-02_missing21
# NYU-02_missing12
# NYU-02_missing13
# NYU-02_missing31
# NYU-02_missing21
# NYU-02_missing25
# NYU-02_missing12
# NYU-02_missing49
# NYU-02_missing38
# NYU-02_missing25
# NYU-02_missing13
# NYU-02_missing26
# NYU-02_missing31
# NYU-02_missing14
# NYU-02_missing22
# NYU-02_missing16
# NYU-02_missing10
# NYU-02_missing15
# NYU-02_missing35
# NYU-02_missing40
# NYU-02_missing15
# NYU-02_missing29
# NYU-02_missing12
# NYU-02_missing65
# NYU-02_missing21
# NYU-02_missing28
# NYU-02_missing15
# NYU-02_missing25
# NYU-02_missing13
# NYU-02_missing41
# NYU-02_missing46
# NYU-02_missing12
# NYU-02_missing12
# NYU-02_missing15
# NYU-02_missing25
# NYU-02_missing17
# NYU-02_missing23
# NYU-02_missing20
# NYU-02_missing14
# NYU-02_missing35
# NYU-02_missing36
# NYU-02_missing53
# NYU-02_missing24
# NYU-02_missing18
# NYU-02_missing23
# NYU-02_missing29
# NYU-02_missing14
# NYU-02_missing15
# NYU-02_missing14
# NYU-02_missing44
# NYU-02_missing10
# NYU-02_missing11
# NYU-04_missing19
# NYU-04_missing15
# NYU-04_missing35
# NYU-04_missing13
# NYU-06_missing17
# NYU-06_missing47
# NYU-06_missing41
# NYU-06_missing32
# NYU-06_missing51
# NYU-06_missing81
# NYU-07_missing16
# NYU-07_missing11
# NYU-07_missing16
# NYU-07_missing22
# NYU-07_missing16
# NYU-07_missing22
# NYU-07_missing26
# NYU-07_missing11
# NYU-07_missing57
# NYU-08_missing12
# NYU-08_missing14
# NYU-08_missing14
# NYU-08_missing22
# NYU-08_missing25
# NYU-08_missing12
# NYU-08_missing20
# NYU-08_missing10
# NYU-09_missing35
# NYU-09_missing15
# NYU-09_missing23
# NYU-09_missing19
# NYU-09_missing25
# NYU-09_missing14
# NYU-09_missing13
# NYU-09_missing32
# NYU-09_missing35
# NYU-21_missing26
# NYU-21_missing49
# NYU-21_missing33
# NYU-21_missing18
# NYU-23_missing15
# NYU-23_missing14
# NYU-23_missing17
# NYU-23_missing12
# NYU-23_missing15
# NYU-23_missing55
# NYU-23_missing64
# NYU-23_missing25
# NYU-23_missing67
# NYU-23_missing51
# NYU-23_missing13
# NYU-23_missing16
# NYU-23_missing21
# NYU-23_missing24
# NYU-23_missing35
# NYU-23_missing34
# NYU-23_missing24
# NYU-23_missing25
# NYU-23_missing16
# NYU-23_missing18
# NYU-23_missing49
# NYU-23_missing24
# NYU-23_missing26
# NYU-23_missing54
# NYU-23_missing39
# NYU-23_missing53
# NYU-23_missing33
# NYU-23_missing72
# NYU-23_missing22
# NYU-23_missing31
# NYU-23_missing12
# NYU-23_missing66
# NYU-23_missing13
# NYU-23_missing14
# NYU-23_missing24
# NYU-23_missing18
# NYU-23_missing34
# NYU-23_missing21
# NYU-23_missing17
# NYU-23_missing44
# NYU-23_missing26
# NYU-23_missing25
# NYU-23_missing32
# NYU-23_missing16
# NYU-23_missing10
# NYU-23_missing44
# NYU-23_missing57
# NYU-23_missing17
# NYU-23_missing45
# NYU-25_missing11
# NYU-25_missing12
# NYU-25_missing23
# NYU-25_missing45
# NYU-25_missing13
# NYU-26_missing11
# NYU-26_missing10
# NYU-26_missing17
# NYU-28_missing12
# NYU-28_missing11
# NYU-28_missing14
# NYU-29_missing35
# NYU-29_missing23
# NYU-29_missing12
# NYU-29_missing44
# NYU-29_missing12
# NYU-30_missing39
# NYU-30_missing11
# NYU-30_missing11
# NYU-30_missing12
# NYU-30_missing10
# NYU-30_missing10
# NYU-30_missing18
# NYU-30_missing17
# NYU-31_missing17
# NYU-31_missing38
# NYU-31_missing11
# NYU-31_missing15
# NYU-31_missing19
# NYU-31_missing12
# NYU-31_missing21
# NYU-31_missing22
# NYU-31_missing11
# NYU-31_missing13
# NYU-31_missing23
# NYU-31_missing12
# NYU-31_missing23
# NYU-31_missing16
# NYU-31_missing12
# NYU-32_missing16
# NYU-32_missing15
# NYU-32_missing10
# NYU-32_missing11
# NYU-38_missing16
# NYU-38_missing12
# NYU-39_missing21
# NYU-39_missing25
# NYU-39_missing12
# NYU-39_missing22
# NYU-39_missing35
# NYU-39_missing12
# NYU-39_missing29
# NYU-39_missing16
# NYU-39_missing13
# NYU-45_missing17
# NYU-45_missing24
# NYU-45_missing13
# NYU-45_missing17
# NYU-45_missing11
# NYU-45_missing10
# NYU-45_missing11
# NYU-45_missing13
# NYU-46_missing13
# NYU-46_missing14
# NYU-46_missing13
# NYU-46_missing14
# NYU-46_missing10
# NYU-46_missing24
# NYU-46_missing15
# NYU-47_missing11
# NYU-47_missing15
# NYU-48_missing14
# NYU-48_missing12
# NYU-48_missing15
# NYU-54_missing12
# NYU-56_missing26
# NYU-56_missing15
# NYU-56_missing45
# NYU-56_missing25
# NYU-56_missing37
# NYU-56_missing12
# NYU-56_missing33
# NYU-58_missing15
# NYU-58_missing13
# NYU-58_missing11
# NYU-58_missing16
# NYU-58_missing33
# NYU-58_missing25
# NYU-58_missing40
# NYU-58_missing12
# SWC_018_missing30
# SWC_018_missing37
# SWC_018_missing11
# SWC_018_missing10
# SWC_018_missing10
# SWC_018_missing13
# SWC_018_missing15
# SWC_018_missing15
# SWC_018_missing37
# SWC_021_missing27
# SWC_021_missing13
# SWC_021_missing20
# SWC_021_missing16
# SWC_021_missing16
# SWC_023_missing27
# SWC_023_missing10
# SWC_023_missing35
# SWC_023_missing13
# SWC_023_missing37
# SWC_023_missing29
# SWC_023_missing12
# SWC_023_missing30
# SWC_023_missing12
# SWC_030_missing11
# SWC_030_missing12
# SWC_030_missing18
# SWC_030_missing22
# SWC_038_missing13
# SWC_038_missing10
# SWC_039_missing10
# SWC_039_missing17
# SWC_039_missing17
# SWC_039_missing13
# SWC_040_missing16
# SWC_040_missing10
# SWC_040_missing13
# SWC_043_missing19
# SWC_043_missing12
# SWC_043_missing25
# SWC_053_missing16
# SWC_053_missing12
# SWC_054_missing11
# UCLA004_missing13
# UCLA004_missing20
# UCLA004_missing18
# UCLA004_missing21
# UCLA004_missing17
# UCLA004_missing24
# UCLA004_missing10
# UCLA004_missing29
# UCLA004_missing16
# UCLA004_missing16
# UCLA004_missing23
# UCLA004_missing73
# UCLA005_missing33
# UCLA005_missing19
# UCLA005_missing12
# UCLA005_missing31
# UCLA005_missing10
# UCLA005_missing16
# UCLA006_missing14
# UCLA006_missing11
# UCLA006_missing16
# UCLA006_missing29
# UCLA006_missing23
# UCLA006_missing28
# UCLA006_missing11
# UCLA006_missing10
# UCLA006_missing22
# UCLA007_missing23
# UCLA007_missing53
# UCLA007_missing24
# UCLA007_missing10
# UCLA007_missing26
# UCLA007_missing36
# UCLA007_missing26
# UCLA007_missing43
# UCLA007_missing19
# UCLA007_missing35
# UCLA007_missing12
# UCLA007_missing13
# UCLA007_missing40
# UCLA007_missing31
# UCLA007_missing22
# UCLA007_missing24
# UCLA007_missing29
# UCLA007_missing15
# UCLA007_missing11
# UCLA007_missing16
# UCLA007_missing23
# UCLA008_missing19
# UCLA008_missing21
# UCLA009_missing63
# UCLA009_missing17
# UCLA009_missing18
# UCLA009_missing14
# UCLA009_missing16
# UCLA009_missing23
# UCLA011_missing18
# UCLA011_missing19
# UCLA011_missing16
# UCLA011_missing11
# UCLA011_missing30
# UCLA011_missing10
# UCLA012_missing19
# UCLA012_missing28
# UCLA012_missing16
# UCLA012_missing41
# UCLA013_missing48
# UCLA013_missing24
# UCLA013_missing32
# UCLA013_missing15
# UCLA013_missing34
# UCLA013_missing22
# UCLA013_missing11
# UCLA014_missing13
# UCLA014_missing12
# UCLA014_missing43
# UCLA014_missing11
# UCLA014_missing21
# UCLA014_missing26
# UCLA015_missing12
# UCLA015_missing21
# UCLA015_missing10
# UCLA015_missing26
# UCLA015_missing36
# UCLA015_missing16
# UCLA015_missing10
# UCLA015_missing29
# UCLA015_missing12
# UCLA015_missing14
# UCLA016_missing15
# UCLA016_missing25
# UCLA016_missing16
# UCLA016_missing11
# UCLA016_missing20
# UCLA016_missing21
# UCLA016_missing11
# UCLA017_missing14
# UCLA017_missing11
# UCLA017_missing18
# UCLA017_missing20
# UCLA017_missing45
# UCLA017_missing12
# UCLA017_missing22
# UCLA017_missing33
# UCLA017_missing10
# UCLA017_missing34
# UCLA017_missing10
# UCLA017_missing28
# UCLA017_missing10
# UCLA017_missing67
# UCLA017_missing23
# UCLA017_missing22
# UCLA017_missing26
# UCLA017_missing10
# UCLA017_missing16
# UCLA017_missing30
# UCLA017_missing17
# UCLA017_missing20
# UCLA017_missing14
# UCLA017_missing10
# UCLA017_missing15
# UCLA017_missing35
# UCLA017_missing24
# UCLA035_missing20
# ZFM-01575_missing13
# ZFM-01575_missing10
# ZFM-01577_missing17
# ZFM-01577_missing27
# ZFM-01594_missing18
# ZFM-01594_missing11
# ZFM-01594_missing17
# ZFM-01937_missing37
# ZFM-01937_missing22
# ZFM-01937_missing20
# ZFM-01937_missing15
# ZFM-02368_missing68
# ZFM-02369_missing16
# ZFM-02371_missing16
# ZFM-02371_missing10
# ZFM-02371_missing10
# ZFM-02371_missing16
# ZFM-02372_missing10
# ZFM-02372_missing11
# ZFM-03841_missing42
# ZFM-03841_missing23
# ZFM-03843_missing13
# ZFM-03843_missing47
# ZFM-03843_missing41
# ZFM-03843_missing15
# ZFM-03843_missing14
# ZFM-03843_missing19
# ZFM-03843_missing14
# ZFM-03843_missing10
# ZFM-03843_missing25
# ZFM-03843_missing21
# ZFM-03843_missing13
# ZFM-03843_missing20
# ZFM-03843_missing12
# ZFM-03843_missing19
# ZFM-03843_missing10
# ZFM-03843_missing14
# ZFM-03843_missing20
# ZFM-04306_missing15
# ZFM-04306_missing10
# ZFM-04306_missing32
# ZFM-04306_missing23
# ZFM-04306_missing10
# ZFM-04306_missing24
# ZFM-04306_missing21
# ZFM-04306_missing12
# ZFM-04306_missing16
# ZFM-04307_missing12
# ZFM-04307_missing26
# ZFM-04307_missing11
# ZFM-04307_missing27
# ZFM-04307_missing16
# ZFM-04307_missing21
# ZFM-04307_missing13
# ZFM-04307_missing30
# ZFM-04307_missing45
# ZFM-04307_missing36
# ZFM-04308_missing14
# ZFM-04308_missing15
# ZFM-04308_missing22
# ZFM-04308_missing11
# ZFM-04308_missing11
# ZFM-04308_missing24
# ZFM-04308_missing18
# ZM_1895_missing21
# ZM_1895_missing28
# ZM_1895_missing10
# ZM_1895_missing25
# ZM_1895_missing13
# ZM_1895_missing11
# ZM_1895_missing11
# ZM_1895_missing17
# ZM_1895_missing14
# ZM_1895_missing18
# ZM_1895_missing15
# ZM_1895_missing20
# ZM_1895_missing41
# ZM_1895_missing11
# ZM_1895_missing33
# ZM_1897_missing23
# ZM_1897_missing12
# ZM_3004_missing12
# ZM_3004_missing13
# ibl_witten_04_missing15
# ibl_witten_04_missing14
# ibl_witten_04_missing21
# ibl_witten_04_missing12
# ibl_witten_06_missing10
# ibl_witten_06_missing18
# ibl_witten_06_missing17
# ibl_witten_06_missing10
# ibl_witten_06_missing17
# ibl_witten_06_missing11
# ibl_witten_06_missing13
# ibl_witten_06_missing10
# ibl_witten_06_missing23
# ibl_witten_06_missing16
# ibl_witten_06_missing11
# ibl_witten_07_missing14
# ibl_witten_07_missing10
# ibl_witten_07_missing15
# ibl_witten_07_missing12
# ibl_witten_07_missing23
# ibl_witten_07_missing11
# ibl_witten_07_missing20
# ibl_witten_07_missing15
# ibl_witten_07_missing12
# ibl_witten_07_missing15
# ibl_witten_12_missing10
# ibl_witten_12_missing16
# ibl_witten_12_missing15
# ibl_witten_12_missing13
# ibl_witten_12_missing17
# ibl_witten_14_missing10
# ibl_witten_14_missing15
# ibl_witten_14_missing11
# ibl_witten_14_missing10
# ibl_witten_18_missing11
# ibl_witten_20_missing11
# ibl_witten_20_missing13
# ibl_witten_20_missing13
# ibl_witten_20_missing24
# ibl_witten_20_missing11
# ibl_witten_20_missing29
# ibl_witten_20_missing12
# ibl_witten_20_missing12
# ibl_witten_21_missing13
# ibl_witten_21_missing25
# ibl_witten_21_missing10
# ibl_witten_23_missing12
# ibl_witten_25_missing12
# ibl_witten_26_missing10
# ibl_witten_26_missing10
# ibl_witten_26_missing10
# ibl_witten_26_missing16
# ibl_witten_26_missing13
# ibl_witten_26_missing26
# ibl_witten_28_missing12
# ibl_witten_28_missing29
# ibl_witten_29_missing10
# ibl_witten_29_missing14
# ibl_witten_30_missing18
# ibl_witten_30_missing69
# ibl_witten_31_missing14
# ibl_witten_32_missing18
# ibl_witten_32_missing15
# ibl_witten_32_missing22
# ibl_witten_32_missing12
# ibl_witten_32_missing17
# ibl_witten_32_missing16
# ibl_witten_32_missing11
# ibl_witten_32_missing17

# %%
def get_animal_name(eid):
    # get session id:
    raw_session_id = eid.split('Subjects/')[1]
    # Get animal:
    animal = raw_session_id.split('/')[0]
    return animal

"""
def get_raw_data(eid, data_dir):
    print(eid)
    # get session id:
    raw_session_id = eid.split('Subjects/')[1]
    # Get animal:
    animal = raw_session_id.split('/')[0]
    # replace '/' with dash in session ID
    session_id = raw_session_id.replace('/', '-')
    # hack to work with ONE:
    current_dir = os.getcwd()
    os.chdir(data_dir)
    # Get choice data, stim data and rewarded/not rewarded:
    choice = one.load_dataset(eid, '_ibl_trials.choice')
    stim_left = one.load_dataset(eid, '_ibl_trials.contrastLeft')
    stim_right = one.load_dataset(eid, '_ibl_trials.contrastRight')
    rewarded = one.load_dataset(eid, '_ibl_trials.feedbackType')
    bias_probs = one.load_dataset(eid, '_ibl_trials.probabilityLeft')
    os.chdir(current_dir)
    return animal, session_id, stim_left, stim_right, rewarded, choice, \
           bias_probs
"""


def get_raw_data(animal, trials_df):
    print(animal)

    # Get data
    choice = np.array(trials_df.loc[trials_df['subject_nickname']==animal,'choice'])
    #choice = np.array(remap_choice_vals(choice))
    stim_left = np.array(trials_df.loc[trials_df['subject_nickname']==animal,'contrastLeft'])
    stim_right = np.array(trials_df.loc[trials_df['subject_nickname']==animal,'contrastRight'])
    rewarded = np.array(trials_df.loc[trials_df['subject_nickname']==animal,'feedbackType'])
    bias_probs = np.array(trials_df.loc[trials_df['subject_nickname']==animal,'probabilityLeft'])
    session_id = trials_df.loc[trials_df['subject_nickname']==animal,'session']
    
    return animal, session_id, stim_left, stim_right, rewarded, choice, \
           bias_probs


def create_stim_vector(stim_left, stim_right):
    # want stim_right - stim_left
    # Replace NaNs with 0:
    stim_left = np.nan_to_num(stim_left, nan=0)
    stim_right = np.nan_to_num(stim_right, nan=0)
    # now get 1D stim
    signed_contrast = stim_right - stim_left
    return signed_contrast


def create_previous_choice_vector(choice):
    ''' choice: choice vector of size T
        previous_choice : vector of size T with previous choice made by
        animal - output is in {0, 1}, where 0 corresponds to a previous left
        choice; 1 corresponds to right.
        If the previous choice was a violation, replace this with the choice
        on the previous trial that was not a violation.
        locs_mapping: array of size (~num_viols)x2, where the entry in
        column 1 is the location in the previous choice vector that was a
        remapping due to a violation and the
        entry in column 2 is the location in the previous choice vector that
        this location was remapped to
    '''
    previous_choice = np.hstack([np.array(choice[0]), choice])[:-1]
    locs_to_update = np.where(previous_choice == -1)[0]
    locs_with_choice = np.where(previous_choice != -1)[0]
    loc_first_choice = locs_with_choice[0]
    locs_mapping = np.zeros((len(locs_to_update) - loc_first_choice, 2),
                            dtype='int')

    for i, loc in enumerate(locs_to_update):
        if loc < loc_first_choice:
            # since no previous choice, bernoulli sample: (not output of
            # bernoulli rvs is in {1, 2})
            previous_choice[loc] = bernoulli.rvs(0.5, 1) - 1
        else:
            # find nearest loc that has a previous choice value that is not
            # -1, and that is earlier than current trial
            potential_matches = locs_with_choice[
                np.where(locs_with_choice < loc)]
            absolute_val_diffs = np.abs(loc - potential_matches)
            absolute_val_diffs_ind = absolute_val_diffs.argmin()
            nearest_loc = potential_matches[absolute_val_diffs_ind]
            locs_mapping[i - loc_first_choice, 0] = int(loc)
            locs_mapping[i - loc_first_choice, 1] = int(nearest_loc)
            previous_choice[loc] = previous_choice[nearest_loc]
    assert len(np.unique(
        previous_choice)) <= 2, "previous choice should be in {0, 1}; " + str(
        np.unique(previous_choice))
    return previous_choice, locs_mapping


def create_wsls_covariate(previous_choice, success, locs_mapping):
    '''
    inputs:
    success: vector of size T, entries are in {-1, 1} and 0 corresponds to
    failure, 1 corresponds to success
    previous_choice: vector of size T, entries are in {0, 1} and 0
    corresponds to left choice, 1 corresponds to right choice
    locs_mapping: location remapping dictionary due to violations
    output:
    wsls: vector of size T, entries are in {-1, 1}.  1 corresponds to
    previous choice = right and success OR previous choice = left and
    failure; -1 corresponds to
    previous choice = left and success OR previous choice = right and failure
    '''
    # remap previous choice vals to {-1, 1}
    remapped_previous_choice = 2 * previous_choice - 1
    previous_reward = np.hstack([np.array(success[0]), success])[:-1]
    # Now need to go through and update previous reward to correspond to
    # same trial as previous choice:
    for i, loc in enumerate(locs_mapping[:, 0]):
        nearest_loc = locs_mapping[i, 1]
        previous_reward[loc] = previous_reward[nearest_loc]
    wsls = previous_reward * remapped_previous_choice
    assert len(np.unique(wsls)) == 2, "wsls should be in {-1, 1}"
    return wsls


def remap_choice_vals(choice):
    # raw choice vector has CW = 1 (correct response for stim on left),
    # CCW = -1 (correct response for stim on right) and viol = 0.  Let's
    # remap so that CW = 0, CCw = 1, and viol = -1
    choice_mapping = {1: 0, -1: 1, 0: -1}
    new_choice_vector = [choice_mapping[old_choice] for old_choice in choice]
    return new_choice_vector


def create_design_mat(choice, stim_left, stim_right, rewarded):
    # Create unnormalized_inpt: with first column = stim_right - stim_left,
    # second column as past choice, third column as WSLS
    stim = create_stim_vector(stim_left, stim_right)
    T = len(stim)
    design_mat = np.zeros((T, 3))
    design_mat[:, 0] = stim
    # make choice vector so that correct response for stim>0 is choice =1
    # and is 0 for stim <0 (viol is mapped to -1)
    choice = remap_choice_vals(choice)
    # create past choice vector:
    previous_choice, locs_mapping = create_previous_choice_vector(choice)
    # create wsls vector:
    wsls = create_wsls_covariate(previous_choice, rewarded, locs_mapping)
    # map previous choice to {-1,1}
    design_mat[:, 1] = 2 * previous_choice - 1
    design_mat[:, 2] = wsls
    return design_mat

"""
def get_all_unnormalized_data_this_session(eid, trials_df):
    # Load raw data
    animal, session_id, stim_left, stim_right, rewarded, choice, bias_probs \
        = get_raw_data(eid, trials_df)
    # Subset choice and design_mat to 50-50 entries:
    trials_to_study = np.where(bias_probs == 0.5)[0]
    trials_to_study = np.where(bias_probs <=1)[0]  # redundant code, but makes sure all trials are used
    num_viols_50 = len(np.where(choice[trials_to_study] == 0)[0])  # viols are omissions
    if num_viols_50 < 10:
        # Create design mat = matrix of size T x 3, with entries for
        # stim/past choice/wsls
        unnormalized_inpt = create_design_mat(choice[trials_to_study],
                                              stim_left[trials_to_study],
                                              stim_right[trials_to_study],
                                              rewarded[trials_to_study])
        y = np.expand_dims(remap_choice_vals(choice[trials_to_study]), axis=1)
        session = [session_id for i in range(y.shape[0])]
        rewarded = np.expand_dims(rewarded[trials_to_study], axis=1)
    else:
        unnormalized_inpt = np.zeros((90, 3))
        y = np.zeros((90, 1))
        session = []
        rewarded = np.zeros((90, 1))
    return animal, unnormalized_inpt, y, session, num_viols_50, rewarded
"""

def get_all_unnormalized_data_this_session(animal, trials_df):
    # Load raw data
    animal, session_id, stim_left, stim_right, rewarded, choice, bias_probs \
        = get_raw_data(animal, trials_df)
    # Subset choice and design_mat to 50-50 entries:
    trials_to_study = np.where(bias_probs == 0.5)[0]
    trials_to_study = np.where(bias_probs <=1)[0]  # redundant code, but makes sure all trials are used
    num_viols_50 = len(np.where(choice[trials_to_study] == 0)[0])  # viols are omissions
    if num_viols_50 < 10:
        # Create design mat = matrix of size T x 3, with entries for
        # stim/past choice/wsls
        unnormalized_inpt = create_design_mat(choice[trials_to_study],
                                              stim_left[trials_to_study],
                                              stim_right[trials_to_study],
                                              rewarded[trials_to_study])
        y = np.expand_dims(remap_choice_vals(choice[trials_to_study]), axis=1)
        session = [session_id for i in range(y.shape[0])]
        rewarded = np.expand_dims(rewarded[trials_to_study], axis=1)
    else:
        unnormalized_inpt = np.zeros((90, 3))
        y = np.zeros((90, 1))
        session = []
        rewarded = np.zeros((90, 1))
    return animal, unnormalized_inpt, y, session, num_viols_50, rewarded


def load_animal_list(file):
    container = np.load(file, allow_pickle=True)
    data = [container[key] for key in container]
    animal_list = data[0]
    return animal_list


def load_animal_eid_dict(file):
    with open(file, 'r') as f:
        animal_eid_dict = json.load(f)
    return animal_eid_dict


def load_data(animal_file):
    container = np.load(animal_file, allow_pickle=True)
    data = [container[key] for key in container]
    inpt = data[0]
    y = data[1]
    y = y.astype('int')
    session = data[2]
    return inpt, y, session


def create_train_test_sessions(session, num_folds=5):
    # create a session-fold lookup table
    num_sessions = len(np.unique(session))
    # Map sessions to folds:
    unshuffled_folds = np.repeat(np.arange(num_folds),
                                 np.ceil(num_sessions / num_folds))
    shuffled_folds = npr.permutation(unshuffled_folds)[:num_sessions]
    assert len(np.unique(
        shuffled_folds)) == 5, "require at least one session per fold for " \
                               "each animal!"
    # Look up table of shuffle-folds:
    sess_id = np.array(np.unique(session), dtype='str')
    shuffled_folds = np.array(shuffled_folds, dtype='O')
    session_fold_lookup_table = np.transpose(
        np.vstack([sess_id, shuffled_folds]))
    return session_fold_lookup_table
"""

def create_train_test_sessions(animal_bin, num_folds=5):
    num_folds = 5
    # create a session-fold lookup table
    bin_len = len(animal_bin)

    # Map trials to folds:
    unshuffled_folds = np.repeat(np.arange(num_folds),
                                    np.ceil(bin_len/ num_folds))
    shuffled_folds = npr.permutation(unshuffled_folds)[:bin_len]
    # make sure final size is the same
    shuffled_folds = shuffled_folds[:bin_len]
    
    return shuffled_folds
"""
# Out:
# '\n\ndef create_train_test_sessions(animal_bin, num_folds=5):\n    num_folds = 5\n    # create a session-fold lookup table\n    bin_len = len(animal_bin)\n\n    # Map trials to folds:\n    unshuffled_folds = np.repeat(np.arange(num_folds),\n                                    np.ceil(bin_len/ num_folds))\n    shuffled_folds = npr.permutation(unshuffled_folds)[:bin_len]\n    # make sure final size is the same\n    shuffled_folds = shuffled_folds[:bin_len]\n    \n    return shuffled_folds\n'
